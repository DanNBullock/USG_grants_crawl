# %% [markdown]
# # USG grants crawl
# ## Ingest
#
# ### Motive
#
# Imagine that we were curious about how the federal governemnt had fostered or otherwise encouraged [open science](https://open.science.gov/) and associated infrastructure in recent years.  How would we even begin to explore this issue?
#
# One potential resource could might be [grants.gov](https://www.grants.gov/web/grants) which serves as an online data resource for government grants in the United States (primarily federal, but also some state).  With this resource it's possible to [explore details about federal grants](https://www.grants.gov/web/grants/search-grants.html), including which agencies are offering them, what they are targeting, and how much funding is available.  It's also possible to [download](https://www.grants.gov/xml-extract.html) much (but not all) of this database for local use.
#
# ### Initial database load
#
# Let's begin by loading up the database provided by the website, which is stored in an xml format.
#
# **Notebook collection-wide note**:  Throughout this collection of notebooks, whenever we first introduce an approach or functionality we will tend to present the majority (if not the entirety) of the code used to produce the results that are being displayed and explored.  This is done for the sake of transparency and learning.  Subsequent applications of established code / functionality will tend to make use of a script collection, `grantsGov_utilities.py`, which is contained in the `src/` directory of this repository.

# %%
from bs4 import BeautifulSoup
import xmltodict
import sys

# FUTURE NOTE: it may be possible to do a check for a local file meeting the relevant criterion and conditionally 
# download from https://www.grants.gov/extract/ (and extract compressed file) in the event a local target isn't found.
# For the moment though...

# load up the xml file; hard-path to local file.  Adjust as necessary
pathToXML='C://Users//dbullock//Documents//code//gitDir//USG_grants_crawl//inputData//GrantsDBExtract20230113v2.xml'

# open and parse file
with open(pathToXML, 'r') as f:
    govGrantData_raw = f.read()

# convert xml to dictionary
with open(pathToXML) as xml_file:
    govGrantData_dictionary = xmltodict.parse(xml_file.read())

# quick size legibility function generated by code-davinci-002
def convert_bytes(bytes):
    if bytes < 1024:
        return str(bytes) + " B"
    elif bytes < 1048576:
        return str(round(bytes/1024, 1)) + " KB"
    elif bytes < 1073741824:
        return str(round(bytes/1048576, 1)) + " MB"
    elif bytes < 1099511627776:
        return str(round(bytes/1073741824, 1)) + " GB"
    else:
        return str(round(bytes/1099511627776, 1)) + " TB"
    
# terminal reports
print('Dictionary conversion successful')
print('\n' + str(len(govGrantData_dictionary['Grants']['OpportunitySynopsisDetail_1_0'])) + ' grant entries found, totalling '+ convert_bytes(sys.getsizeof(govGrantData_raw)))
#print('\n and with dictionary keys:\n')
#print(govGrantData_dictionary['Grants']['OpportunitySynopsisDetail_1_0'][0].keys())
# Out:
# Dictionary conversion successful
#
# 70330 grant entries found, totalling 256.2 MB

# %% [markdown]
# ### What does a grant record look like
#
# To get a sense of what any give grant records looks like in the XML structure / metadata scheme / python dictionary, we can select one arbitrarly and view it.

# %%
print("{" + "\n".join("{!r}: {!r},".format(k, v) for k, v in  govGrantData_dictionary['Grants']['OpportunitySynopsisDetail_1_0'][1].items()) + "}")
# Out:
# {'OpportunityID': '262149',
# 'OpportunityTitle': 'Eradication of Yellow Crazy Ants on Johnston Atoll NWR',
# 'OpportunityNumber': 'F14AS00402',
# 'OpportunityCategory': 'D',
# 'FundingInstrumentType': 'CA',
# 'CategoryOfFundingActivity': ['AG', 'ENV', 'NR'],
# 'CFDANumbers': '15.608',
# 'EligibleApplicants': '99',
# 'AdditionalInformationOnEligibility': 'The recipient has already been selected for this award.  Please see attached Notice of Intent to Award for specifics.',
# 'AgencyCode': 'DOI-FWS',
# 'AgencyName': 'Fish and Wildlife Service',
# 'PostDate': '08152014',
# 'CloseDate': '08222014',
# 'LastUpdatedDate': '08152014',
# 'AwardCeiling': '0',
# 'AwardFloor': '0',
# 'EstimatedTotalProgramFunding': '0',
# 'Description': 'Funds under this award are to be used for the eradication of Yellow Crazy Ants from Johnston Atoll National Wildlife Refuge.',
# 'Version': 'Synopsis 1',
# 'CostSharingOrMatchingRequirement': 'No',
# 'ArchiveDate': '08232014',
# 'AdditionalInformationURL': 'http://www.grants.gov/',
# 'AdditionalInformationText': 'http://www.grants.gov/',
# 'GrantorContactEmail': 'Connie_Sauer@fws.gov',
# 'GrantorContactEmailDescription': 'Connie_Sauer@fws.gov',
# 'GrantorContactText': 'Connie Sauer, 503-490-0827&lt;br/&gt;Connie_Sauer@fws.gov&lt;br/&gt;',}

# %% [markdown]
# ### A quick conversion and freeing up memory
#
# We're not going to need all of the information that's contained in the XML database, at least not for the majority of the investigations we'll be pursuing.  Additionally, indexing into an unstructured data object like this likely isn't the most resource or time efficient approach.  As such, let's go ahead and get the data fields we _do_ want, and drop the rest (to free up memory).

# %%
import pandas as pd
# convert to pandas dataframe
grantsDF=pd.DataFrame.from_records(govGrantData_dictionary['Grants']['OpportunitySynopsisDetail_1_0'], columns=['OpportunityID', 'OpportunityTitle','OpportunityNumber','AgencyCode', 'AgencyName', 'AwardCeiling', 'AwardFloor', 'EstimatedTotalProgramFunding', 'ExpectedNumberOfAwards', 'Description'])
# proactively replace nans for agency name with other
# replace the nans
grantsDF=grantsDF.fillna(0)
# free up memory
del govGrantData_dictionary

grantsDF.head(50)
# Out:
#    OpportunityID                                   OpportunityTitle  \
# 0         262148  Establishment of the Edmund S. Muskie Graduate...
# 1         262149  Eradication of Yellow Crazy Ants on Johnston A...
# 2         131073  Cooperative Ecosystem Studies Unit, Piedmont S...
# 3         131094  Plant Feedstock Genomics for Bioenergy:  A Joi...
# 4         131095  Management of HIV-Related Lung Disease and Car...
# 5         131093         Shared Instrumentation Grant Program (S10)
# 6         262168                       Idaho BLM - Croy Creek Trail
# 7         262188  Assessment of Population, Reproductive, and He...
# 8         262189  Office of Elementary and Secondary Education (...
# 9         262190  Office of Elementary and Secondary Education (...
# 10        131113     Rheumatic Diseases Research Core Centers (P30)
# 11        262191                            Recovery Best Practices
# 12        262192  BLM OR-WA West Eugene Wetlands Environmental E...
# 13        262193  Digital Asset Management, Geographic Informati...
# 14        131133  NIDDK Mentored Research Scientist Development ...
# 15        262208  BLM OR-WA Umpqua Basin Oak Habitat Restoration...
# 16        262209             Youth Living History Musicians Program
# 17        262228  Prevention of Lower Urinary Tract Symptoms in ...
# 18        262229                          Night Vision Technologies
# 19        262230  SEA LEVEL MONITORING AND GEOGRAPHIC INFORMATIO...
# 20        262231  Laboratory Systems Strengthening Services to C...
# 21        262232  Piping Plover Adaptive Management Support for ...
# 22        131174                             Recreation User Survey
# 23        131175  Socioeconomic Impacts of the North Cumberland ...
# 24        131173               Benthic Macro-Invertebrate Inventory
# 25        262248  Prevention of Lower Urinary Tract Symptoms in ...
# 26        262249  Monitoring Estuarine Condition at Colonial NHP...
# 27        262268  MD-PhD Training Program in Aging and the Socia...
# 28        262269  Benthic Macroinvertebrate Monitoring for Vario...
# 29        262270                    FY 2015 Joint Hurricane Testbed
# 30        262271  Notice of Intent to Issue FOA: DE-FOA-0001162,...
# 31        131193  Outreach and Assistance for Socially Disadvant...
# 32        262272  BLM OR-WA Tillamook Estuaries Partnership&apos...
# 33        262273  BLM OR-WA Tillamook Estuaries Partnership&apos...
# 34        131213  Technology Development to Enable Large Scale M...
# 35        262288  BLM OR-WA Honey Creek Diversions Passage and S...
# 36        262289  National Park Service-Historic Diversity Resea...
# 37        262308  Health and resiliency of salt marshes in Jamai...
# 38        262309  Request for Information (RFI) on Landscape Des...
# 39        262310  Operation and Maintenance of the Rio Grande Si...
# 40        262311     Lewiston Orchards Project Pilot Water Exchange
# 41        131233  Scale-Up of Care and Support Services for Orph...
# 42        262312                FY 2014 CCSP The Outdoor Foundation
# 43        131253  FY 2012 Request for Proposals from Indian Trib...
# 44        262328      FY15 Consolidated Innovative Nuclear Research
# 45        262329  FY2015 Scientific Infrastructure Support for C...
# 46        262348                                       GBV TechCamp
# 47        131273  Midcareer Investigator Award in Mouse Pathobio...
# 48        131293                 Wildlife Restoration Grant Program
# 49        262368  Post-Hurricane Sandy submerged marine habitat ...
#
#                 OpportunityNumber       AgencyCode  \
# 0   SCAPPD-14-AW-161-SCA-08152014           DOS-SA
# 1                      F14AS00402          DOI-FWS
# 2                      G12AS20003        DOI-USGS1
# 3                  DE-FOA-0000598          PAMS-SC
# 4                   RFA-HL-12-034        HHS-NIH11
# 5                      PAR-12-017        HHS-NIH11
# 6                      L14AS00315          DOI-BLM
# 7                      F14AS00404          DOI-FWS
# 8            ED-GRANTS-081814-001               ED
# 9            ED-GRANTS-081814-002               ED
# 10                  RFA-AR-12-002        HHS-NIH11
# 11                  EP-HIT-14-002      HHS-OS-ASPR
# 12                     L14AS00308          DOI-BLM
# 13                     P14AS00266          DOI-NPS
# 14                     PAR-12-020        HHS-NIH11
# 15                     L14AS00316          DOI-BLM
# 16                     P14AS00267          DOI-NPS
# 17                  RFA-DK-14-018        HHS-NIH11
# 18               W909MY-14-R-D010  DOD-AMC-ACCAPGB
# 19                     P14AS00268          DOI-NPS
# 20              CDC-RFA-GH15-1536          HHS-CDC
# 21                     P14AS00264          DOI-NPS
# 22          NPS-12-NOIBISO-100102          DOI-NPS
# 23          NPS-12-NOIBISO-100103          DOI-NPS
# 24          NPS-12-NOIBISO-100101          DOI-NPS
# 25                  RFA-DK-14-004        HHS-NIH11
# 26                     P14AS00269          DOI-NPS
# 27                  RFA-AG-15-012        HHS-NIH11
# 28                     P14AS00270          DOI-NPS
# 29     NOAA-OAR-OWAQ-2015-2004200              DOC
# 30                 DE-FOA-0001177          DOE-GFO
# 31                      OAO-00005        USDA-OPPE
# 32                     L14AS00318          DOI-BLM
# 33                     L14AS00320          DOI-BLM
# 34                  RFA-RM-11-019        HHS-NIH11
# 35                     L14AS00321          DOI-BLM
# 36              NPS-NOIP14AC01530          DOI-NPS
# 37               NPS-14-NERO-0119          DOI-NPS
# 38                 DE-FOA-0001178          DOE-GFO
# 39                     R14SS00015          DOI-BOR
# 40                     R14AS00071          DOI-BOR
# 41                 RFA-620-11-012        USAID-NIG
# 42                     P14AS00272          DOI-NPS
# 43              EPA-OW-OWOW-12-01              EPA
# 44                 DE-FOA-0001129           DOE-ID
# 45                 DE-FOA-0001130           DOE-ID
# 46                      MRFP14-02          DOS-IND
# 47                     PAR-12-021        HHS-NIH11
# 48                     WR-2011-R4          DOI-FWS
# 49               NPS-14-NERO-0125          DOI-NPS
#
#                                            AgencyName AwardCeiling AwardFloor  \
# 0           Bureau of South and Central Asian Affairs       600000     400000
# 1                           Fish and Wildlife Service            0          0
# 2                                   Geological Survey            0          0
# 3                                   Office of Science       500000     200000
# 4                       National Institutes of Health       400000          0
# 5                       National Institutes of Health            0          0
# 6                           Bureau of Land Management        95000          0
# 7                           Fish and Wildlife Service       250000     150000
# 8                             Department of Education            0          0
# 9                             Department of Education            0          0
# 10                      National Institutes of Health       400000          0
# 11  Assistant Secretary for Preparedness and Response        90000      50000
# 12                          Bureau of Land Management         3000          1
# 13                              National Park Service       659210          1
# 14                      National Institutes of Health            0          0
# 15                          Bureau of Land Management       108302          1
# 16                              National Park Service            0          0
# 17                      National Institutes of Health       750000          0
# 18                                    ACC-APG-Belvoir            0          0
# 19                              National Park Service       135431          1
# 20         Centers for Disease Control and Prevention      1000000          0
# 21                              National Park Service            0          0
# 22                              National Park Service       137110     137110
# 23                              National Park Service        59267      59267
# 24                              National Park Service        30971      30971
# 25                      National Institutes of Health       500000          0
# 26                              National Park Service            0          0
# 27                      National Institutes of Health            0          0
# 28                              National Park Service            0          0
# 29                             Department of Commerce       150000          0
# 30                                Golden Field Office            0          0
# 31      Office of Partnerships and Public Engagements       800000          0
# 32                          Bureau of Land Management        25646          1
# 33                          Bureau of Land Management        35000          1
# 34                      National Institutes of Health            0          0
# 35                          Bureau of Land Management        13840          1
# 36                              National Park Service            0          0
# 37                              National Park Service       275897     275897
# 38                                Golden Field Office            0          0
# 39                              Bureau of Reclamation       743285          1
# 40                              Bureau of Reclamation       554867          0
# 41                                Nigeria USAID-Abuja     32500000          0
# 42                              National Park Service       386000          1
# 43                    Environmental Protection Agency       150000          0
# 44                                 Idaho Field Office      5000000          1
# 45                                 Idaho Field Office       800000          1
# 46                              U.S. Mission to India       120000      80000
# 47                      National Institutes of Health            0          0
# 48                          Fish and Wildlife Service            0          0
# 49                              National Park Service       480000     480000
#
#    EstimatedTotalProgramFunding ExpectedNumberOfAwards  \
# 0                        600000                      1
# 1                             0                      0
# 2                         31900                      1
# 3                       6000000                     10
# 4                       2000000                      0
# 5                      43000000                    110
# 6                         95000                      1
# 7                        250000                      1
# 8                      80000000                      5
# 9                     160000000                      7
# 10                      1200000                      0
# 11                            0                      0
# 12                       250000                      1
# 13                       659210                      1
# 14                            0                      0
# 15                       200000                      1
# 16                            0                      0
# 17                      4500000                      0
# 18                            0                      0
# 19                       135431                      1
# 20                            0                      1
# 21                        10000                      1
# 22                       137110                      1
# 23                        59267                      1
# 24                        30971                      1
# 25                      4500000                      0
# 26                            0                      0
# 27                       800000                      4
# 28                            0                      0
# 29                       700000                      6
# 30                            0                      0
# 31                     19000000                     70
# 32                       200000                      1
# 33                       500000                      1
# 34                     10000000                      0
# 35                       500000                      1
# 36                        30000                      1
# 37                       275897                      1
# 38                            0                      0
# 39                       743285                      1
# 40                       554867                      0
# 41                     65000000                      2
# 42                       386000                      1
# 43                      3000000                     25
# 44                            0                     65
# 45                      6500000                     22
# 46                       120000                      1
# 47                            0                      0
# 48                            0                      0
# 49                       480000                      1
#
#                                           Description
# 0   The Office of Press and Public Diplomacy of th...
# 1   Funds under this award are to be used for the ...
# 2   The USGS Southeast Ecological Science Center s...
# 3   The U.S. Department of Energy&apos;s Office of...
# 4   This FOA invites clinical trials planning gran...
# 5   The NCRR Shared Instrument Grant (SIG) program...
# 6   Reestablish the Croy Creek Trail Network to al...
# 7   This program will provide assistance to an ins...
# 8   Note: Each funding opportunity description is ...
# 9   Note: Each funding opportunity description is ...
# 10  The National Institute of Arthritis and Muscul...
# 11  The Assistant Secretary for Preparedness and R...
# 12  The purpose of this program is to provide yout...
# 13  NOTICE OF INTENT TO AWARD This Funding Announc...
# 14  The purpose of the National Institute of Diabe...
# 15  The Secure Rural Schools Act provides funding ...
# 16  Establish a youth living history Civil War Jr....
# 17  This Funding Opportunity Announcement (FOA) in...
# 18  As &quot;The Army&apos;s Sensor Developer,&quo...
# 19  NOTICE OF INTENT TO AWARD This Funding Announc...
# 20  The Ministry of Health (MOH) in Burma and the ...
# 21  This project starts a cooperative relationship...
# 22  United States Department of the Interior, Nati...
# 23  United States Department of the Interior, Nati...
# 24  United States Department of the Interior, Nati...
# 25  This Funding Opportunity Announcement (FOA) in...
# 26  Continuation of monitoring both estuarine wate...
# 27  NIA&apos;s MD-PhD Institutional Training Progr...
# 28  Processing and identifying benthic macroinvert...
# 29  The Office of Oceanic and Atmospheric Research...
# 30  The Office of Energy Efficiency and Renewable ...
# 31  This notice announces the availability of fund...
# 32  This partnership started in 2003 and included ...
# 33  This partnership started in 2003 and included ...
# 34  This FOA is intended to support the developmen...
# 35  This is a project to improve fish passage at t...
# 36  This action will result in a task agreement aw...
# 37  NOTICE OF INTENT TO AWARD This Funding Announc...
# 38  The United States (U.S.) Department of Energy ...
# 39  The primary purpose of this grant is for the C...
# 40  This Funding Announcement is not a request for...
# 41  The United States Government, represented by t...
# 42  NOTICE OF INTENT TO AWARD This Funding Announc...
# 43  FY 2012 Request for Proposals from Indian Trib...
# 44  The Department of Energy&#146;s (DOE) Office o...
# 45  The Department of Energy&#146;s (DOE) Office o...
# 46  The United States and India are partnering in ...
# 47  This Funding Opportunity Announcement (FOA), u...
# 48  Excise taxes on firearms, ammunitions, archery...
# 49  NOTICE OF INTENT TO AWARD This Funding Announc...

# %% [markdown]
# ### Does the data need cleaning?
#
# As with every case when working with a data source, we need to ask ourselves if our data is reliable and/or if it needs cleaning.  As it turns out, we do indeed need to clean this data.  For example, all of the numbers in our dataframe are currently considered strings, which will not be useful if we want to do math later.
#
# In a number of instances, there no information entered in the fields relating to the agency identity.  We'll have to group these in an `Other` category, for now.  Additionally the AgencyCode field likely has more information than we need, so we can fix that too.
#
# One of the major issues though, is the incorrect information being entered in the `ExpectedNumberOfAwards` field.  For grants which do not have a `EstimatedTotalProgramFunding`, we use this in combination with the grant ceiling and floor to estimate what this ought to be.  When an unreliable number is entered here it can really throw off later computations.  We won't change this at the moment, but instead implement a threshold beyond which we won't trust the number.
#
# NOTE: A much more comprehensive and robust cleaning approach is implemented in `grantsGov_utilities.prepareGrantsDF` and `grantsGov_utilities.repairFunding_GovGrantsDf`

# %%
# let's do some initial dataset overview
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from itertools import compress
from IPython.display import display, HTML

grantsDF[['AwardCeiling','AwardFloor','EstimatedTotalProgramFunding','ExpectedNumberOfAwards']]=grantsDF[['AwardCeiling','AwardFloor','EstimatedTotalProgramFunding','ExpectedNumberOfAwards']].astype(np.int64)

display((grantsDF[['OpportunityID','AgencyName','EstimatedTotalProgramFunding','AwardCeiling','AwardFloor','ExpectedNumberOfAwards']].sort_values(by='ExpectedNumberOfAwards')).iloc[-50:])


# ideally, the names would all be formatted the same and reliable, allowing us to just index into a pandas column. 
# however, they're not, so we have to use this approach, and attempt to replace unreliable ones.

# find the list elements where the agency full name was not available (i.e. worst case), and thus set to NAN (which was then replaced with 0)
grantsDF['AgencyName'].loc[grantsDF['AgencyName'].eq(0)]='Other'
# this will serve as a backstop in the event no information was provided

# in the event no agency code is provided (and thus set to 0) use the capital letters of the agency name
grantsDF['AgencyCode'].loc[grantsDF['AgencyCode'].eq(0)]=grantsDF['AgencyName'].loc[grantsDF['AgencyCode'].eq(0)].map(lambda x: ''.join([char for char in x if char.isupper()]))

# however, we don't want to have surreptitiously created the 'O' agency, so set 'O' to other, instead of the abbreviation
grantsDF['AgencyCode'].loc[grantsDF['AgencyCode'].eq('O')]='Other'

# also remove everything after the first hyphen.  We dont need to go that far down for this in the hirearchy
grantsDF['AgencyCode']=grantsDF['AgencyCode'].map(lambda x: x.split('-',1)[0])

# let's save down this fixed dataframe to speed up later analyses, 
# NOTE can't use comma as separator due to Description content.  Use Bar instead?
grantsDF.to_csv('allGrantsData.csv', sep='|')
# Out:
#       OpportunityID                                        AgencyName  \
# 12425        287495       Department of Housing and Urban Development
# 66712        251274            Department of Homeland Security - FEMA
# 17758        295436                             National Park Service
# 6580         279192                             National Park Service
# 19056        297091                         Fish and Wildlife Service
# 4533         276884                         Fish and Wildlife Service
# 6115         278651                             National Park Service
# 27033        175873                         Bureau of Land Management
# 43664         60036                             National Park Service
# 10751        284299                             National Park Service
# 10750        284298                             National Park Service
# 51295        202115                         Fish and Wildlife Service
# 67782        253926                         Bureau of Land Management
# 28776        177153                         Fish and Wildlife Service
# 11604        285929                         Fish and Wildlife Service
# 5648         278112                         Fish and Wildlife Service
# 5038         277432                         Fish and Wildlife Service
# 55066        338134                             U.S. Mission to Japan
# 4114         276364                             National Park Service
# 41411         56996                         Bureau of Land Management
# 29730        177874                         Fish and Wildlife Service
# 19905        298498           Air Force Office of Scientific Research
# 25606        305996           Air Force Office of Scientific Research
# 6011         278529                         Fish and Wildlife Service
# 49577        331000                            Bangladesh USAID-Dhaka
# 11287        285299                             Bureau of Reclamation
# 21787        170593                             National Park Service
# 23138         41494                           Department of Education
# 29702         46784        Centers for Disease Control and Prevention
# 53081        335320                    Agricultural Marketing Service
# 57193        210177     Bureau of Reclamation - Lower Colorado Region
# 66057        249177                         Bureau of Land Management
# 52039        334084           Air Force Office of Scientific Research
# 44028        322842                     National Institutes of Health
# 32644         49623                             National Park Service
# 11515        285737                         Bureau of Land Management
# 59645        214673  Centers for Disease Control and Prevention - ERA
# 63061        235798                           Department of Education
# 61317         96793                           Department of Education
# 39561         55527                           Department of Education
# 68728        256711        Centers for Disease Control and Prevention
# 37641         54055                           Department of Education
# 3381         275506                     National Institutes of Health
# 40557         56289        Centers for Disease Control and Prevention
# 42972         58820       Department of Housing and Urban Development
# 42970         58818       Department of Housing and Urban Development
# 35956        314753           Air Force Office of Scientific Research
# 42969         58817       Department of Housing and Urban Development
# 311          132413       Department of Housing and Urban Development
# 52935        204054        National Institute of Food and Agriculture
#
#        EstimatedTotalProgramFunding  AwardCeiling  AwardFloor  \
# 12425                    1900000000       1500000        2500
# 66712                      32092008             0           0
# 17758                         26965             0           0
# 6580                              1             0           0
# 19056                             0         30000           0
# 4533                              0             1           0
# 6115                              1             0           0
# 27033                         40000         40000       10000
# 43664                             1             0           0
# 10751                         45345             1           1
# 10750                         47834         47834       47834
# 51295                         50000         50000           0
# 67782                           500         50000         500
# 28776                             1         52000           0
# 11604                             1         53716       53716
# 5648                          60000         60000       60000
# 5038                              0             1           0
# 55066                         70000         70000       25000
# 4114                          75800         75800       75800
# 41411                        400000         80000       80000
# 29730                         93880         93880           0
# 19905                             0      80000000        3000
# 25606                             0     100000000        3000
# 6011                              1        100000      100000
# 49577                             0            10           1
# 11287                        104165        104165      104165
# 21787                        149000             0           0
# 23138                             1             0           0
# 29702                             1        175000      175000
# 53081                     650000000         20000        1500
# 57193                        200000         25000           0
# 66057                             5        125000      125000
# 52039                             0     100000000        3000
# 44028                             1        675000           0
# 32644                             0             0           0
# 11515                       1290000      10000000           0
# 59645                        500000        500000      500000
# 63061                             8             0           0
# 61317                             1       1996000           0
# 39561                            10        450000      350000
# 68728                             5        750000           0
# 37641                            25        150000           0
# 3381                              0        225000           0
# 40557                            53         50000       23500
# 42972                             0             0           0
# 42970                             0             0           0
# 35956                             0     100000000        3000
# 42969                             0             0           0
# 311                               0             0           0
# 52935                             0             0           0
#
#        ExpectedNumberOfAwards
# 12425                    8000
# 66712                   10000
# 17758                   26965
# 6580                    27240
# 19056                   30000
# 4533                    30740
# 6115                    36698
# 27033                   40000
# 43664                   44471
# 10751                   45345
# 10750                   47834
# 51295                   50000
# 67782                   50000
# 28776                   52000
# 11604                   53716
# 5648                    60000
# 5038                    67319
# 55066                   70000
# 4114                    75800
# 41411                   80000
# 29730                   93880
# 19905                   99999
# 25606                   99999
# 6011                   100000
# 49577                  100000
# 11287                  104165
# 21787                  149000
# 23138                  154046
# 29702                  175000
# 53081                  200000
# 57193                  200000
# 66057                  500000
# 52039                  999999
# 44028                 1000000
# 32644                 1031000
# 11515                 1290000
# 59645                 1500000
# 63061                 1866402
# 61317                 1996000
# 39561                 3424802
# 68728                 3750000
# 37641                 3750000
# 3381                  4000000
# 40557                 4250000
# 42972                 6755000
# 42970                 8000000
# 35956                 9999999
# 42969                26000000
# 311                  40050000
# 52935               264000000
# C:\Users\dbullock\AppData\Local\Temp\1\ipykernel_38712\521758451.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grantsDF['AgencyName'].loc[grantsDF['AgencyName'].eq(0)]='Other'
# C:\Users\dbullock\AppData\Local\Temp\1\ipykernel_38712\521758451.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grantsDF['AgencyCode'].loc[grantsDF['AgencyCode'].eq(0)]=grantsDF['AgencyName'].loc[grantsDF['AgencyCode'].eq(0)].map(lambda x: ''.join([char for char in x if char.isupper()]))
# C:\Users\dbullock\AppData\Local\Temp\1\ipykernel_38712\521758451.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grantsDF['AgencyCode'].loc[grantsDF['AgencyCode'].eq('O')]='Other'

# %% [markdown]
# ### Quick inspection of the dataset
#
# Now that the data has been downloaded and cleaned, let's take a moment to take a look at the the broad scope of the database.  To do this, we'll look at it from an agency-based perspective, and see how many grants are recorded as well as what their total funding is.
#
# Keep in mind that, although this is a fairly comprehensive database, it may not include all grants, and even the grant records it _does_ contain may all not be formatted in a standard way (and thus may be overlooked by the method we employ here).
#
# We'll also save down this output to the working directory, in a file named `agencyGrantsSummary.csv`.

# %%
# we can go ahead and compute the frequencies for these as well
# get the unique entries and their counts
unique_elements, counts_elements = np.unique(list(grantsDF['AgencyCode'].values), return_counts=True)
#get the proportions thereof
countPortions=np.divide(counts_elements,np.sum(counts_elements))

#Now that we have the names, we can obtain other information using this same approach
 
#seems that the data can be unreliable, particualrly when we implement the grant funding estimate that comes up shortly
sanityGrantThresh=2000
    
#do the same but for the grant values
grantValVec=[[] for iGrant in range(grantsDF.shape[0]) ]
for iIndex,iListing in grantsDF.iterrows():
        # place the current estimate info in a variable
        currEstimate=np.int64(iListing['EstimatedTotalProgramFunding']) 
        # if it's not == 0, set it as the value
        if not currEstimate == 0: 
            grantValVec[iIndex]=currEstimate
        # otherwise use the ceiling and floor
        # NOTE: in the event that the ceiling and floor won't provided, they will have been NANs in the initial DataFrame
        # this was then replaced with 0
        # the mean of 0 * 1 = 0, so the following is mathematically fine
        else:
            # take the mean and use that times the number of potential awards
            # if the number of expected awards is 0 or too large, treat it as 1
            if iListing['ExpectedNumberOfAwards'] == 0 or np.int64(iListing['ExpectedNumberOfAwards']) >= sanityGrantThresh :
                expectedAwards=1
                #otherwise use the information provided
            else: 
                expectedAwards=np.int64(iListing['ExpectedNumberOfAwards'])
                
            grantValVec[iIndex]=np.mean([np.int64(iListing['AwardCeiling']),np.int64(iListing['AwardFloor'])])*expectedAwards

# if you ever want to demonstrate why you ought to do sanity checks, try this without setting the sanity grantNum threshold:
#GrantValOrder=np.flip(np.argsort(grantValVec))
#grantsDF[['OpportunityID','AgencyName','EstimatedTotalProgramFunding','AwardCeiling','AwardFloor','ExpectedNumberOfAwards']].iloc[GrantValOrder[0:5
#
# also you can use this to check and see where the 2000 threshold came from
# grantsDF[['AwardCeiling','AwardFloor','EstimatedTotalProgramFunding','ExpectedNumberOfAwards']]=grantsDF[['AwardCeiling','AwardFloor','EstimatedTotalProgramFunding','ExpectedNumberOfAwards']].astype(np.int64)
# (grantsDF[['OpportunityID','AgencyName','EstimatedTotalProgramFunding','AwardCeiling','AwardFloor','ExpectedNumberOfAwards']].sort_values(by='ExpectedNumberOfAwards')).iloc[-100:-50]
# Note that those grants that DO have accurate grant numbers in this range, have an accurate estimated award.
# this means the loop never gets this far in such a case.

#use that information to get the total value for each agency
#initialize a vector for the totals
agencyTotals=np.zeros(len(unique_elements))
for iAgencyIndex,iUniqueAgencies in enumerate(unique_elements):
    agencyVecMask=[iUniqueAgencies==iAgencies for iAgencies in list(grantsDF['AgencyCode'].values)]
    agencyTotals[iAgencyIndex]=np.sum(list(compress(grantValVec,agencyVecMask)))

#get the proportions thereof
valueProportion=np.divide(agencyTotals,np.sum(agencyTotals))
            
#initialize the dataframe
grantCountDF=pd.DataFrame(data=zip(unique_elements,counts_elements,countPortions,agencyTotals,valueProportion),columns=['AgencyName','GrantCount','PortionOfTotal','TotalValue','TotalValuePortion'])

# save it down
grantCountDF.to_csv('../agencyGrantsSummary.csv')
# interactive display, we'll display 100 MB worth, max
pd.options.display.float_format = '{:,.5f}'.format
grantCountDF
# Out:
#    AgencyName  GrantCount  PortionOfTotal            TotalValue  \
# 0          AC          14         0.00020      36,340,000.00000
# 1        CNCS         103         0.00146     446,533,570.00000
# 2        CPSC           9         0.00013      14,900,005.00000
# 3          DC           8         0.00011      53,320,000.00000
# 4         DHS        1373         0.01952 134,645,308,722.50000
# 5         DOC        1168         0.01661  14,636,620,100.50000
# 6         DOD        3474         0.04940  56,181,063,624.50000
# 7         DOE        1426         0.02028  56,439,521,213.00000
# 8         DOI       19804         0.28159  27,190,785,173.50000
# 9         DOL         609         0.00866  51,614,437,185.00000
# 10        DOS        5580         0.07934   8,111,702,446.50000
# 11        DOT        1112         0.01581 164,329,369,640.00000
# 12        ECP           1         0.00001     129,700,000.00000
# 13         ED        1443         0.02052 125,281,232,947.00000
# 14        EPA        1287         0.01830   6,896,188,598.00000
# 15        FCC           2         0.00003     178,500,000.00000
# 16       FMCS           6         0.00009       2,965,000.00000
# 17       GDIT           3         0.00004               6.50000
# 18        GSA           1         0.00001         500,000.00000
# 19        HHS       20087         0.28561 228,576,860,307.50000
# 20        HUD         504         0.00717  41,627,201,532.00000
# 21       IMLS          99         0.00141     493,481,000.00000
# 22        LOC          10         0.00014       1,502,500.00000
# 23        MCC          24         0.00034     139,792,500.00000
# 24       NARA         148         0.00210     140,590,000.00000
# 25       NASA        1416         0.02013     712,523,260.00000
# 26        NCD          29         0.00041       2,890,000.00000
# 27       NCUA           7         0.00010       1,201,500.00000
# 28        NEA         197         0.00280     215,055,100.00000
# 29        NEH         537         0.00764     912,934,831.50000
# 30        NRC          50         0.00071     199,082,212.00000
# 31        NSF        1095         0.01557  18,363,100,043.00000
# 32       ODNI           1         0.00001       7,500,000.00000
# 33      ONDCP          33         0.00047     122,934,536.50000
# 34      Other          43         0.00061     142,291,756.00000
# 35       PAMS         347         0.00493  20,140,797,618.50000
# 36        SBA         206         0.00293   3,921,717,739.00000
# 37        SSA          19         0.00027     166,111,518.00000
# 38      USAID        2727         0.03877  82,604,336,550.00000
# 39       USDA        2329         0.03312 215,900,490,329.50000
# 40      USDOJ        2744         0.03902  36,001,721,643.00000
# 41      USDOT         158         0.00225  21,469,083,602.50000
# 42      USEAC           7         0.00010      11,600,000.00000
# 43         VA          88         0.00125   3,214,900,000.00000
# 44        WWC           2         0.00003       2,760,000.00000
#
#     TotalValuePortion
# 0             0.00003
# 1             0.00034
# 2             0.00001
# 3             0.00004
# 4             0.10191
# 5             0.01108
# 6             0.04252
# 7             0.04272
# 8             0.02058
# 9             0.03906
# 10            0.00614
# 11            0.12437
# 12            0.00010
# 13            0.09482
# 14            0.00522
# 15            0.00014
# 16            0.00000
# 17            0.00000
# 18            0.00000
# 19            0.17300
# 20            0.03151
# 21            0.00037
# 22            0.00000
# 23            0.00011
# 24            0.00011
# 25            0.00054
# 26            0.00000
# 27            0.00000
# 28            0.00016
# 29            0.00069
# 30            0.00015
# 31            0.01390
# 32            0.00001
# 33            0.00009
# 34            0.00011
# 35            0.01524
# 36            0.00297
# 37            0.00013
# 38            0.06252
# 39            0.16340
# 40            0.02725
# 41            0.01625
# 42            0.00001
# 43            0.00243
# 44            0.00000

# %% [markdown]
# ### What about open-science-specific grants?
#
# In this notebook we have looked at the data contained within the [grants.gov](https://www.grants.gov/web/grants) export.  In the next notebook ('Open Science Overview'), we'll take a first look at this data more specifically through the lense of open-science infrastructure.
